# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Ensure the notebook can find the /src directory
root_path = Path.cwd().parent
if str(root_path) not in sys.path:
    sys.path.append(str(root_path))

# %%
from src.data_loader import VesselDataLoader

# %%
# Path to your raw telemetry
raw_data_file1 = root_path / "data" / "raw" / "Rotherhithe_voy_179.csv"
raw_data_file2 = root_path / "data" / "raw" / "Wembley_voy_236.csv"

# Instantiate
loader1 = VesselDataLoader(raw_data_file1)
loader2 = VesselDataLoader(raw_data_file2)

# Load and clean the data
df1 = loader1.load_and_clean()
df2 = loader2.load_and_clean()
# Out:
# Successfully loaded, cleaned, and processed 2880 telemetry rows.
# Successfully loaded, cleaned, and processed 3168 telemetry rows.

# %%
loader1.sanity_check()
loader2.sanity_check()
# Out:
# ==================================================
# TELEMETRY SANITY CHECK REPORT: Rotherhithe_voy_179.csv
# ==================================================
# [1] Basic Metrics:
#     Total Rows: 2880
#     WARNING: 3 missing values detected across the dataframe.
# ROT_DEG_PER_MIN    1
# POWER_TV_ENERGY    1
# PF_DERIVATIVE      1
#
# [2] Time-Grid Continuity:
#     Strictly Monotonic Time Index: Pass
#     Pass: No significant time gaps detected.
#
# [3] Physical Boundary Checks:
#     Pass: All engineered physical features within realistic bounds.
#
# [4] System Logic & Energy Balance:
#     Pass: Mean power balance within acceptable limits (1.10 kW).
#     WARNING: 6 logical contradictions detected (STATUS='Idle' but Speed > 10 knots).
#     This suggests manual log lagging by the crew.
# ==================================================
# ==================================================
# TELEMETRY SANITY CHECK REPORT: Wembley_voy_236.csv
# ==================================================
# [1] Basic Metrics:
#     Total Rows: 3168
#     WARNING: 3 missing values detected across the dataframe.
# ROT_DEG_PER_MIN    1
# POWER_TV_ENERGY    1
# PF_DERIVATIVE      1
#
# [2] Time-Grid Continuity:
#     Strictly Monotonic Time Index: Pass
#     Pass: No significant time gaps detected.
#
# [3] Physical Boundary Checks:
#     Pass: All engineered physical features within realistic bounds.
#
# [4] System Logic & Energy Balance:
#     Pass: Mean power balance within acceptable limits (1.15 kW).
#     WARNING: 3 logical contradictions detected (STATUS='Idle' but Speed > 10 knots).
#     This suggests manual log lagging by the crew.
# ==================================================
