# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Align local repository execution paths
sys.path.append(os.path.abspath('../src'))
from utils.viz import build_interactive_dashboard

# %%
build_interactive_dashboard(
    schedule_path='../src/config/schedule.json',
    weather_path='../src/config/weather_params.json'
)
